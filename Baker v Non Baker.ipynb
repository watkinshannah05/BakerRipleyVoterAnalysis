# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator

# %%
harris_precincts = pd.read_csv('/Users/okuse/Downloads/red605_county_vtd_22g_population.csv')

# %%
harris_precincts.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2   Total  Unnamed: 4   Anglo Non-Anglo  \
# 0        NaN        NaN         NaN     NaN         NaN     NaN       NaN
# 1   Anderson     Total:         NaN  57,922         NaN  33,098    24,824
# 2        NaN       VAP:         NaN  47,381         NaN  27,667    19,714
# 3          1     Total:         NaN   3,153         NaN   1,660     1,493
# 4        NaN       VAP:         NaN   2,340         NaN   1,347       993
#
#    Unnamed: 7  Unnamed: 8 Asian  ... Unnamed: 13 %Anglo %Non-Anglo  \
# 0         NaN         NaN   NaN  ...         NaN    NaN        NaN
# 1         NaN         NaN   543  ...         NaN   57.1       42.9
# 2         NaN         NaN   396  ...         NaN   58.4       41.6
# 3         NaN         NaN    53  ...         NaN   52.6       47.4
# 4         NaN         NaN    40  ...         NaN   57.6       42.4
#
#    Unnamed: 16  Unnamed: 17  %Asian  %Black  %Hispanic  Unnamed: 21  %B+H
# ...

# %%
harris_precincts.drop(['Unnamed: 2'], axis=1, inplace=True)

# %%
harris_precincts.drop(['Unnamed: 4', 'Unnamed: 7', 'Unnamed: 13'], axis=1, inplace=True)

# %%
harris_precincts.drop(['Unnamed: 8', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 21'], axis=1, inplace=True)

# %%
harris_precincts.drop(0, axis=0, inplace=True)

# %%
harris_precincts.iloc[8732]
# Out:
# Unnamed: 0       Harris
# Unnamed: 1       Total:
# Total         4,731,145
# Anglo         1,309,593
# Non-Anglo     3,421,552
# Asian           392,435
# Black           981,484
# Hisp          2,034,709
# B+H           2,967,268
# %Anglo             27.7
# %Non-Anglo         72.3
# %Asian              8.3
# %Black             20.7
# %Hispanic          43.0
# %B+H               62.7
# Name: 8733, dtype: object

# %%
harris_precincts.truncate(before=8733)
# Out:
#       Unnamed: 0 Unnamed: 1      Total      Anglo  Non-Anglo    Asian  \
# 8733      Harris     Total:  4,731,145  1,309,593  3,421,552  392,435
# 8734         NaN       VAP:  3,519,584  1,075,663  2,443,921  302,348
# 8735           1     Total:      1,979      1,140        839      193
# 8736         NaN       VAP:      1,644        959        685      157
# 8737           2     Total:      4,770      2,565      2,205      472
# ...          ...        ...        ...        ...        ...      ...
# 20025        NaN       VAP:      1,075        149        926        4
# 20026       001a     Total:      1,432         87      1,345       14
# 20027        NaN       VAP:        956         69        887       11
# 20028       004a     Total:        956         54        902        1
# 20029        NaN       VAP:        681         46        635        1
#
#          Black       Hisp        B+H  %Anglo  %Non-Anglo  %Asian  %Black  \
# ...

# %%
harris_precincts = harris_precincts.truncate(before=8733)

# %%
harris_precincts.reset_index()
# Out:
#        index Unnamed: 0 Unnamed: 1      Total      Anglo  Non-Anglo    Asian  \
# 0       8733     Harris     Total:  4,731,145  1,309,593  3,421,552  392,435
# 1       8734        NaN       VAP:  3,519,584  1,075,663  2,443,921  302,348
# 2       8735          1     Total:      1,979      1,140        839      193
# 3       8736        NaN       VAP:      1,644        959        685      157
# 4       8737          2     Total:      4,770      2,565      2,205      472
# ...      ...        ...        ...        ...        ...        ...      ...
# 11292  20025        NaN       VAP:      1,075        149        926        4
# 11293  20026       001a     Total:      1,432         87      1,345       14
# 11294  20027        NaN       VAP:        956         69        887       11
# 11295  20028       004a     Total:        956         54        902        1
# 11296  20029        NaN       VAP:        681         46        635        1
#
# ...

# %%
harris_precincts = harris_precincts.fillna('')

# %%
harris_precincts.iloc[2337]
# Out:
# Unnamed: 0    Harrison
# Unnamed: 1      Total:
# Total           68,839
# Anglo           42,039
# Non-Anglo       26,800
# Asian              718
# Black           14,553
# Hisp             9,839
# B+H             24,107
# %Anglo            61.1
# %Non-Anglo        38.9
# %Asian             1.0
# %Black            21.1
# %Hispanic         14.3
# %B+H              35.0
# Name: 11070, dtype: object

# %%
harris_precincts = harris_precincts.reset_index()

# %%
harris_precincts = harris_precincts.truncate(after=2336)

# %%
harris_precincts.drop(['index'], axis=1, inplace=True)

# %%
harris_precincts.rename(columns = {'Unnamed: 0':'Precincts', 'Unnamed: 1':'Population'}, inplace = True)

# %%
total_precincts = pd.DataFrame(harris_precincts)

# %%
target_precincts1 = total_precincts.iloc[18:24]
target_precincts2 = total_precincts.iloc[88:90]
target_precincts3 = total_precincts.iloc[94:96]
target_precincts4 = total_precincts.iloc[572:574]
target_precincts5 = total_precincts.iloc[696:698]
target_precincts6 = total_precincts.iloc[760:762]
target_precincts7 = total_precincts.iloc[824:826]
target_precincts8 = total_precincts.iloc[862:866]
target_precincts9 = total_precincts.iloc[1332:1334]
target_precincts10 = total_precincts.iloc[1508:1510]
target_precincts11 = total_precincts.iloc[1588:1592]

# %%
target_precincts = pd.concat([target_precincts1, target_precincts2, target_precincts3, target_precincts4, target_precincts5, target_precincts6, target_precincts7, target_precincts8, target_precincts9, target_precincts10, target_precincts11], axis=0)

# %%
target_precincts
# Out:
#      Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 18           9     Total:   4,044    931     3,113    201  1,261   1,640
# 19                   VAP:   3,280    872     2,408    171    890   1,312
# 20          10     Total:   3,587    385     3,202     68    143   2,991
# 21                   VAP:   2,902    332     2,570     55    127   2,379
# 22          11     Total:   3,492    295     3,197     62    194   2,962
# 23                   VAP:   2,784    275     2,509     49    173   2,294
# 88          44     Total:   3,799    564     3,235     70    229   2,924
# 89                   VAP:   2,980    472     2,508     50    187   2,253
# 94          46     Total:   5,033    471     4,562     76    949   3,531
# 95                   VAP:   3,810    425     3,385     62    542   2,767
# 572        285     Total:   5,334    148     5,186     38  1,979   3,188
# 573                  VAP:   3,985    121     3,864     28  1,627   2,215
# ...

# %%
# All Target Precincts, excluding one, are at most 40% White/Anglo. Excluding one, all have Asian %s between 0 and 5.5%.

# %%
# % Black is rather variable, so it will not be used for identifying comparable precincts. % Hispanic is at least 30%.

# %%
# % Black and Hispanic is at least 60%, excluding one or two precincts.

# %%
print(harris_precincts.dtypes)
harris_precincts['%Non-Anglo'] = pd.to_numeric(harris_precincts['%Non-Anglo'])
harris_precincts['%Anglo'] = pd.to_numeric(harris_precincts['%Anglo'])
harris_precincts['%Asian'] = pd.to_numeric(harris_precincts['%Asian'])
harris_precincts['%Black'] = pd.to_numeric(harris_precincts['%Black'])
harris_precincts['%Hispanic'] = pd.to_numeric(harris_precincts['%Hispanic'])
harris_precincts['%B+H'] = pd.to_numeric(harris_precincts['%B+H'])
harris_precincts = harris_precincts[harris_precincts['%Non-Anglo'] > 60.0]
# Out:
# Precincts     object
# Population    object
# Total         object
# Anglo         object
# Non-Anglo     object
# Asian         object
# Black         object
# Hisp          object
# B+H           object
# %Anglo        object
# %Non-Anglo    object
# %Asian        object
# %Black        object
# %Hispanic     object
# %B+H          object
# dtype: object

# %%
harris_precincts.dtypes
# Out:
# Precincts      object
# Population     object
# Total          object
# Anglo          object
# Non-Anglo      object
# Asian          object
# Black          object
# Hisp           object
# B+H            object
# %Anglo        float64
# %Non-Anglo    float64
# %Asian        float64
# %Black        float64
# %Hispanic     float64
# %B+H          float64
# dtype: object

# %%
harris_precincts
# Out:
#      Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0       Harris     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 1                    VAP:  3,519,584  1,075,663  2,443,921  302,348  712,166
# 12           6     Total:      8,814      2,294      6,520      292    2,862
# 13                   VAP:      6,379      1,945      4,434      224    1,916
# 14           7     Total:      1,294         32      1,262        9      754
# ...        ...        ...        ...        ...        ...      ...      ...
# 2299                 VAP:        119         15        104        2        6
# 2300      1148     Total:      2,720        163      2,557      273      578
# 2301                 VAP:      1,970        139      1,831      236      409
# 2302      1149     Total:      5,720      2,099      3,621      411    1,573
# 2303                 VAP:      3,945      1,529      2,416      285    1,080
#
# ...

# %%
harris_precincts.shape
# Out:
# (1460, 15)

# %%
harris_precincts
# Out:
#      Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0       Harris     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 1                    VAP:  3,519,584  1,075,663  2,443,921  302,348  712,166
# 12           6     Total:      8,814      2,294      6,520      292    2,862
# 13                   VAP:      6,379      1,945      4,434      224    1,916
# 14           7     Total:      1,294         32      1,262        9      754
# ...        ...        ...        ...        ...        ...      ...      ...
# 2299                 VAP:        119         15        104        2        6
# 2300      1148     Total:      2,720        163      2,557      273      578
# 2301                 VAP:      1,970        139      1,831      236      409
# 2302      1149     Total:      5,720      2,099      3,621      411    1,573
# 2303                 VAP:      3,945      1,529      2,416      285    1,080
#
# ...

# %%
harris_precincts = harris_precincts.reset_index()
harris_precincts
# Out:
#       index Precincts Population      Total      Anglo  Non-Anglo    Asian  \
# 0         0    Harris     Total:  4,731,145  1,309,593  3,421,552  392,435
# 1         1                 VAP:  3,519,584  1,075,663  2,443,921  302,348
# 2        12         6     Total:      8,814      2,294      6,520      292
# 3        13                 VAP:      6,379      1,945      4,434      224
# 4        14         7     Total:      1,294         32      1,262        9
# ...     ...       ...        ...        ...        ...        ...      ...
# 1455   2299                 VAP:        119         15        104        2
# 1456   2300      1148     Total:      2,720        163      2,557      273
# 1457   2301                 VAP:      1,970        139      1,831      236
# 1458   2302      1149     Total:      5,720      2,099      3,621      411
# 1459   2303                 VAP:      3,945      1,529      2,416      285
#
# ...

# %%
harris_precincts.drop(['index'], axis=1, inplace=True)

# %%
harris_precincts
# Out:
#      Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0       Harris     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 1                    VAP:  3,519,584  1,075,663  2,443,921  302,348  712,166
# 2            6     Total:      8,814      2,294      6,520      292    2,862
# 3                    VAP:      6,379      1,945      4,434      224    1,916
# 4            7     Total:      1,294         32      1,262        9      754
# ...        ...        ...        ...        ...        ...      ...      ...
# 1455                 VAP:        119         15        104        2        6
# 1456      1148     Total:      2,720        163      2,557      273      578
# 1457                 VAP:      1,970        139      1,831      236      409
# 1458      1149     Total:      5,720      2,099      3,621      411    1,573
# 1459                 VAP:      3,945      1,529      2,416      285    1,080
#
# ...

# %%
harris_precincts['Precincts'] = harris_precincts['Precincts'].shift()

# %%
harris_precincts
# Out:
#      Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0          NaN     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 1       Harris       VAP:  3,519,584  1,075,663  2,443,921  302,348  712,166
# 2                  Total:      8,814      2,294      6,520      292    2,862
# 3            6       VAP:      6,379      1,945      4,434      224    1,916
# 4                  Total:      1,294         32      1,262        9      754
# ...        ...        ...        ...        ...        ...      ...      ...
# 1455      1147       VAP:        119         15        104        2        6
# 1456               Total:      2,720        163      2,557      273      578
# 1457      1148       VAP:      1,970        139      1,831      236      409
# 1458               Total:      5,720      2,099      3,621      411    1,573
# 1459      1149       VAP:      3,945      1,529      2,416      285    1,080
#
# ...

# %%
ripley_nums = [9, 10, 11, 44, 46, 285, 347, 379, 411, 430, 431, 664, 752, 792, 793]
harris_precincts_0 = harris_precincts[harris_precincts.Precincts != "Harris"]
harris_precincts_0 = harris_precincts_0[harris_precincts_0.Precincts != ""]
harris_precincts_0 = harris_precincts_0[harris_precincts_0.Precincts != "0045a"]
harris_precincts_0.dropna(inplace=True)

harris_precincts_0['Precincts'] = pd.to_numeric(harris_precincts_0['Precincts'])

# %%
target_audience = pd.read_csv('clean_target_audience.csv')
target_audience['PrecinctName'] = target_audience['PrecinctName'].str.replace('Harris - ', '')
target_audience['PrecinctName'] = target_audience['PrecinctName'].astype('int64')
target_audience
# Out:
#        Unnamed: 0    Voter ID      City   Zip5  Age Sex  PrecinctName
# 0               0  1122198569   Houston  77009   59   F            46
# 1               1  1114307920   Houston  77003   63   M            10
# 2               2  1186408232  Pasadena  77504   74   F           347
# 3               3  1161567574  Pasadena  77504   53   F           752
# 4               4  1068564056   Houston  77026   56   M            46
# ...           ...         ...       ...    ...  ...  ..           ...
# 22041       22041  2183568938   Houston  77087   19   F           285
# 22042       22042  2191650739  Pasadena  77504   21   M           752
# 22043       22043  2167872180   Houston  77003   54   F            10
# 22044       22044  2184783273  Pasadena  77504   25   F           793
# 22045       22045  2190466288   Houston  77009   28   F            46
#
# [22046 rows x 7 columns]

# %%
# registered = pd.read_csv('registered_voters.csv')
# registered = registered[registered['Voter ID',]]
# registered

# %%
non_ripley_precincts = harris_precincts_0[harris_precincts_0['Precincts'].isin(ripley_nums) == False]
ripley_precincts = harris_precincts_0[harris_precincts_0['Precincts'].isin(ripley_nums) == True]
non_ripley_precincts
# Out:
#       Precincts Population  Total  Anglo Non-Anglo Asian  Black   Hisp    B+H  \
# 3             6       VAP:  6,379  1,945     4,434   224  1,916  2,277  4,095
# 5             7       VAP:    987     27       960     9    627    328    952
# 13           12       VAP:  1,259    291       968    15    172    757    926
# 15           13       VAP:  5,315  1,967     3,348   119    876  2,250  3,068
# 17           17       VAP:  1,625    457     1,168   223    291    650    931
# ...         ...        ...    ...    ...       ...   ...    ...    ...    ...
# 1451       1139       VAP:  4,987    358     4,629   158  1,774  2,716  4,456
# 1453       1140       VAP:    270    101       169     8    102     58    156
# 1455       1147       VAP:    119     15       104     2      6     98    104
# 1457       1148       VAP:  1,970    139     1,831   236    409  1,198  1,593
# 1459       1149       VAP:  3,945  1,529     2,416   285  1,080  1,016  2,063
#
# ...

# %%
ripley_precincts
# Out:
#       Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 7             9       VAP:   3,280    872     2,408    171    890   1,312
# 9            10       VAP:   2,902    332     2,570     55    127   2,379
# 11           11       VAP:   2,784    275     2,509     49    173   2,294
# 50           44       VAP:   2,980    472     2,508     50    187   2,253
# 54           46       VAP:   3,810    425     3,385     62    542   2,767
# 362         285       VAP:   3,985    121     3,864     28  1,627   2,215
# 451         347       VAP:   5,783  1,721     4,062    262    183   3,571
# 493         379       VAP:   2,458     78     2,380     16  1,182   1,206
# 542         411       VAP:   4,796    427     4,369     51    320   4,006
# 571         430       VAP:   5,556    560     4,996  1,216    949   2,876
# 573         431       VAP:  15,519    975    14,544  1,309  3,207  10,085
# 860         664       VAP:   5,810    322     5,488     78    473   4,933
# ...

# %%
def mse(result, expected):
    """
    Calculate the mean squared error between two data sets.

    The length of the inputs, result and expected, must be the same.

    inputs:
        - result: a list of integers or floats representing the actual output
        - expected: a list of integers or floats representing the predicted output

    returns: a float that is the mean squared error between the two data sets
    """
    # will hold the sum of the squared errors
    total = 0
    # get the squared errors and add them to total for each individual prediction
    for index in range(len(result)):
        diff = result[index] - expected[index]
        total += (diff ** 2)
    # get the mean squared error
    return total/len(result)

# %%
mse_data = {}
for precinct in ripley_nums:
    mse_data[precinct] = []


x = 0
while x < non_ripley_precincts.shape[0]:
    row = non_ripley_precincts.iloc[x]
    result = list(row[9:])
    y = 0
    while y < ripley_precincts.shape[0]:
        rip = ripley_precincts.iloc[y]
        expected = list(rip[9:])
        diff = mse(result, expected)
        mse_data[int(rip[0])].append(diff)
        y += 1
    x += 1

# %%
# All remaining precincts are comparable to the target precincts. So, 15 will be selected randomly to compare to the original 15 targeted by BakerRipley.

# %%
# Find the most similar precinct
similar = []
list()
for key in mse_data:
    
    dat = mse_data[key]
    ind = dat.index(min(dat))
    precinct = non_ripley_precincts.iloc[ind][0]
    similar.append(precinct)

    
print(ripley_nums)
print(similar)
# Out:
# [9, 10, 11, 44, 46, 285, 347, 379, 411, 430, 431, 664, 752, 792, 793]
# [498, 241, 339, 266, 248, 171, 207, 344, 72, 1113, 366, 942, 973, 341, 364]

# %%
similar_precincts = non_ripley_precincts[non_ripley_precincts.Precincts.isin(similar) == True]
similar_precincts
# Out:
#       Precincts Population  Total Anglo Non-Anglo Asian  Black   Hisp    B+H  \
# 80           72       VAP:  3,505   319     3,186    32    182  2,984  3,148
# 200         171       VAP:  2,682    78     2,604    31  1,095  1,480  2,568
# 248         207       VAP:  1,367   440       927    30     22    877    893
# 296         241       VAP:  5,590   635     4,955   138    249  4,559  4,790
# 307         248       VAP:  3,931   440     3,491    22    576  2,871  3,409
# 334         266       VAP:  5,076   785     4,291    61    333  3,896  4,208
# 439         339       VAP:  3,197   298     2,899    42    269  2,584  2,836
# 441         341       VAP:  2,495   151     2,344     7    396  1,942  2,323
# 447         344       VAP:  1,482    33     1,449     8    707    738  1,434
# 469         364       VAP:  3,514   744     2,770   135    247  2,366  2,594
# 473         366       VAP:  7,254   369     6,885   910  1,408  4,582  5,948
# ...

# %%
ripley_precincts
# Out:
#       Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 7             9       VAP:   3,280    872     2,408    171    890   1,312
# 9            10       VAP:   2,902    332     2,570     55    127   2,379
# 11           11       VAP:   2,784    275     2,509     49    173   2,294
# 50           44       VAP:   2,980    472     2,508     50    187   2,253
# 54           46       VAP:   3,810    425     3,385     62    542   2,767
# 362         285       VAP:   3,985    121     3,864     28  1,627   2,215
# 451         347       VAP:   5,783  1,721     4,062    262    183   3,571
# 493         379       VAP:   2,458     78     2,380     16  1,182   1,206
# 542         411       VAP:   4,796    427     4,369     51    320   4,006
# 571         430       VAP:   5,556    560     4,996  1,216    949   2,876
# 573         431       VAP:  15,519    975    14,544  1,309  3,207  10,085
# 860         664       VAP:   5,810    322     5,488     78    473   4,933
# ...

# %%
voters_1 = pd.read_csv('nov_voters_1.csv', low_memory=False)
voters_2 = pd.read_csv('nov_voters_2.csv', low_memory=False)
voters_3 = pd.read_csv('nov_voters_3.csv', low_memory=False)

temp = pd.concat([voters_1, voters_2])
voters = pd.concat([temp, voters_3])
voters.drop(['Unnamed: 0', 'DATE_VOTED', 'Voting Site', 'Congressional House District'], inplace=True, axis=1)

voters.head()
# Out:
#        Voter ID VOTE_TYPE     CITY    ZIP SEX BIRTHYEAR  Voting Precinct
# 0  1.102134e+09         P  HOUSTON  77007   M      1952                1
# 1  1.102253e+09         P  HOUSTON  77009   F      1947                1
# 2  1.102030e+09         E  HOUSTON  77007   F      1944                1
# 3  1.102253e+09         M  HOUSTON  77009   F      1948                1
# 4  1.102253e+09         P  HOUSTON  77009   M      1949                1

# %%
rip_rates = []
sim_rates = []
for idx in range(len(similar)):
    rip = voters[voters['Voting Precinct'] == ripley_nums[idx]].shape[0]
    sim = voters[voters['Voting Precinct'] == similar[idx]].shape[0]
    rip_vap = int(ripley_precincts.iloc[idx][2].replace(',', ''))
    rip_rate = round((rip/rip_vap)*100, 2)
    temp = similar_precincts[similar_precincts['Precincts'] == similar[idx]]
    sim_vap = int(temp.iloc[0][2].replace(',', ''))
    sim_rate = round((sim/sim_vap)*100, 2)
    rip_rates.append(rip_rate)
    sim_rates.append(sim_rate)

# %%
labels = [("#"+str(rip), "#"+str(sim)) for rip, sim in zip(ripley_nums, similar)]
print(labels)

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots()
rip_bars = ax.bar(x - width/2, rip_rates, width, label="Baker Ripley Targeted Precincts", color='#3d54c8')
sim_bars = ax.bar(x + width/2, sim_rates, width, label="Other Harris County Precincts", color='#95e1e9')

ax.set_ylabel('Voter Turnout')
ax.set_title('Voter Turnout in Baker Ripley Targeted Precincts vs Other Harris County Precincts')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rip_bars, padding=1.5)
ax.bar_label(sim_bars, padding=1.5)

for ax in fig.axes:
    ax.yaxis.set_major_locator(MultipleLocator(5))
    
fig.set_size_inches(20, 5)
fig.tight_layout()
plt.show()
# Out:
# [('#9', '#498'), ('#10', '#241'), ('#11', '#339'), ('#44', '#266'), ('#46', '#248'), ('#285', '#171'), ('#347', '#207'), ('#379', '#344'), ('#411', '#72'), ('#430', '#1113'), ('#431', '#366'), ('#664', '#942'), ('#752', '#973'), ('#792', '#341'), ('#793', '#364')]
