# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
harris_precincts = pd.read_csv('/Users/data30nana/Downloads/red605_county_vtd_22g_population.csv')

# %%
harris_precincts.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2   Total  Unnamed: 4   Anglo Non-Anglo  \
# 0        NaN        NaN         NaN     NaN         NaN     NaN       NaN
# 1   Anderson     Total:         NaN  57,922         NaN  33,098    24,824
# 2        NaN       VAP:         NaN  47,381         NaN  27,667    19,714
# 3          1     Total:         NaN   3,153         NaN   1,660     1,493
# 4        NaN       VAP:         NaN   2,340         NaN   1,347       993
#
#    Unnamed: 7  Unnamed: 8 Asian  ... Unnamed: 13 %Anglo %Non-Anglo  \
# 0         NaN         NaN   NaN  ...         NaN    NaN        NaN
# 1         NaN         NaN   543  ...         NaN   57.1       42.9
# 2         NaN         NaN   396  ...         NaN   58.4       41.6
# 3         NaN         NaN    53  ...         NaN   52.6       47.4
# 4         NaN         NaN    40  ...         NaN   57.6       42.4
#
#    Unnamed: 16  Unnamed: 17  %Asian  %Black  %Hispanic  Unnamed: 21  %B+H
# ...

# %%
harris_precincts.drop(['Unnamed: 2'], axis=1, inplace=True)

# %%
harris_precincts.drop(['Unnamed: 4', 'Unnamed: 7', 'Unnamed: 13'], axis=1, inplace=True)

# %%
harris_precincts.drop(['Unnamed: 8', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 21'], axis=1, inplace=True)

# %%
harris_precincts.drop(0, axis=0, inplace=True)

# %%
harris_precincts.iloc[8732]
# Out:
# Unnamed: 0       Harris
# Unnamed: 1       Total:
# Total         4,731,145
# Anglo         1,309,593
# Non-Anglo     3,421,552
# Asian           392,435
# Black           981,484
# Hisp          2,034,709
# B+H           2,967,268
# %Anglo             27.7
# %Non-Anglo         72.3
# %Asian              8.3
# %Black             20.7
# %Hispanic          43.0
# %B+H               62.7
# Name: 8733, dtype: object

# %%
harris_precincts.truncate(before=8733)
# Out:
#       Unnamed: 0 Unnamed: 1      Total      Anglo  Non-Anglo    Asian  \
# 8733      Harris     Total:  4,731,145  1,309,593  3,421,552  392,435
# 8734         NaN       VAP:  3,519,584  1,075,663  2,443,921  302,348
# 8735           1     Total:      1,979      1,140        839      193
# 8736         NaN       VAP:      1,644        959        685      157
# 8737           2     Total:      4,770      2,565      2,205      472
# ...          ...        ...        ...        ...        ...      ...
# 20025        NaN       VAP:      1,075        149        926        4
# 20026       001a     Total:      1,432         87      1,345       14
# 20027        NaN       VAP:        956         69        887       11
# 20028       004a     Total:        956         54        902        1
# 20029        NaN       VAP:        681         46        635        1
#
#          Black       Hisp        B+H  %Anglo  %Non-Anglo  %Asian  %Black  \
# ...

# %%
harris_precincts = harris_precincts.truncate(before=8733)

# %%
harris_precincts.reset_index()
# Out:
#        index Unnamed: 0 Unnamed: 1      Total      Anglo  Non-Anglo    Asian  \
# 0       8733     Harris     Total:  4,731,145  1,309,593  3,421,552  392,435
# 1       8734        NaN       VAP:  3,519,584  1,075,663  2,443,921  302,348
# 2       8735          1     Total:      1,979      1,140        839      193
# 3       8736        NaN       VAP:      1,644        959        685      157
# 4       8737          2     Total:      4,770      2,565      2,205      472
# ...      ...        ...        ...        ...        ...        ...      ...
# 11292  20025        NaN       VAP:      1,075        149        926        4
# 11293  20026       001a     Total:      1,432         87      1,345       14
# 11294  20027        NaN       VAP:        956         69        887       11
# 11295  20028       004a     Total:        956         54        902        1
# 11296  20029        NaN       VAP:        681         46        635        1
#
# ...

# %%
harris_precincts = harris_precincts.fillna('')

# %%
harris_precincts.iloc[2337]
# Out:
# index            11070
# Unnamed: 0    Harrison
# Unnamed: 1      Total:
# Total           68,839
# Anglo           42,039
# Non-Anglo       26,800
# Asian              718
# Black           14,553
# Hisp             9,839
# B+H             24,107
# %Anglo            61.1
# %Non-Anglo        38.9
# %Asian             1.0
# %Black            21.1
# %Hispanic         14.3
# %B+H              35.0
# Name: 2337, dtype: object

# %%
harris_precincts = harris_precincts.reset_index()

# %%
harris_precincts = harris_precincts.truncate(after=2336)

# %%
harris_precincts.drop(['index'], axis=1, inplace=True)

# %%
harris_precincts.rename(columns = {'Unnamed: 0':'Precincts', 'Unnamed: 1':'Population'}, inplace = True)

# %%
total_precincts = pd.DataFrame(harris_precincts)

# %%
target_precincts1 = total_precincts.iloc[18:24]
target_precincts2 = total_precincts.iloc[88:90]
target_precincts3 = total_precincts.iloc[94:96]
target_precincts4 = total_precincts.iloc[572:574]
target_precincts5 = total_precincts.iloc[696:698]
target_precincts6 = total_precincts.iloc[760:762]
target_precincts7 = total_precincts.iloc[824:826]
target_precincts8 = total_precincts.iloc[862:866]
target_precincts9 = total_precincts.iloc[1332:1334]
target_precincts10 = total_precincts.iloc[1508:1510]
target_precincts11 = total_precincts.iloc[1588:1592]

# %%
target_precincts = pd.concat([target_precincts1, target_precincts2, target_precincts3, target_precincts4, target_precincts5, target_precincts6, target_precincts7, target_precincts8, target_precincts9, target_precincts10, target_precincts11], axis=0)

# %%
target_precincts
# Out:
#      Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 18           9     Total:   4,044    931     3,113    201  1,261   1,640
# 19                   VAP:   3,280    872     2,408    171    890   1,312
# 20          10     Total:   3,587    385     3,202     68    143   2,991
# 21                   VAP:   2,902    332     2,570     55    127   2,379
# 22          11     Total:   3,492    295     3,197     62    194   2,962
# 23                   VAP:   2,784    275     2,509     49    173   2,294
# 88          44     Total:   3,799    564     3,235     70    229   2,924
# 89                   VAP:   2,980    472     2,508     50    187   2,253
# 94          46     Total:   5,033    471     4,562     76    949   3,531
# 95                   VAP:   3,810    425     3,385     62    542   2,767
# 572        285     Total:   5,334    148     5,186     38  1,979   3,188
# 573                  VAP:   3,985    121     3,864     28  1,627   2,215
# ...

# %%
# All Target Precincts, excluding one, are at most 40% White/Anglo. Excluding one, all have Asian %s between 0 and 5.5%.

# %%
# % Black is rather variable, so it will not be used for identifying comparable precincts. % Hispanic is at least 30%.

# %%
# % Black and Hispanic is at least 60%, excluding one or two precincts.

# %%
print(harris_precincts.dtypes)
harris_precincts['%Non-Anglo'] = pd.to_numeric(harris_precincts['%Non-Anglo'])
harris_precincts['%Anglo'] = pd.to_numeric(harris_precincts['%Anglo'])
harris_precincts['%Asian'] = pd.to_numeric(harris_precincts['%Asian'])
harris_precincts['%Black'] = pd.to_numeric(harris_precincts['%Black'])
harris_precincts['%Hispanic'] = pd.to_numeric(harris_precincts['%Hispanic'])
harris_precincts['%B+H'] = pd.to_numeric(harris_precincts['%B+H'])
harris_precincts = harris_precincts[harris_precincts['%Non-Anglo'] > 60.0]
# Out:
# Precincts      object
# Population     object
# Total          object
# Anglo          object
# Non-Anglo      object
# Asian          object
# Black          object
# Hisp           object
# B+H            object
# %Anglo         object
# %Non-Anglo    float64
# %Asian         object
# %Black         object
# %Hispanic      object
# %B+H           object
# dtype: object
# C:\Users\data30nana\AppData\Local\Temp\ipykernel_11776\3932089323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harris_precincts['%Non-Anglo'] = pd.to_numeric(harris_precincts['%Non-Anglo'])
# C:\Users\data30nana\AppData\Local\Temp\ipykernel_11776\3932089323.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
harris_precincts.dtypes
# Out:
# Precincts      object
# Population     object
# Total          object
# Anglo          object
# Non-Anglo      object
# Asian          object
# Black          object
# Hisp           object
# B+H            object
# %Anglo        float64
# %Non-Anglo    float64
# %Asian        float64
# %Black        float64
# %Hispanic     float64
# %B+H          float64
# dtype: object

# %%
harris_precincts
# Out:
#      Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0       Harris     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 1                    VAP:  3,519,584  1,075,663  2,443,921  302,348  712,166
# 12           6     Total:      8,814      2,294      6,520      292    2,862
# 13                   VAP:      6,379      1,945      4,434      224    1,916
# 14           7     Total:      1,294         32      1,262        9      754
# ...        ...        ...        ...        ...        ...      ...      ...
# 2299                 VAP:        119         15        104        2        6
# 2300      1148     Total:      2,720        163      2,557      273      578
# 2301                 VAP:      1,970        139      1,831      236      409
# 2302      1149     Total:      5,720      2,099      3,621      411    1,573
# 2303                 VAP:      3,945      1,529      2,416      285    1,080
#
# ...

# %%
harris_precincts = harris_precincts[harris_precincts['%Asian'] <= 12.0]

# %%
harris_precincts = harris_precincts[harris_precincts['%Hispanic'] >= 30.0]

# %%
harris_precincts = harris_precincts[harris_precincts['%B+H'] >= 60.0]

# %%
harris_precincts.shape
# Out:
# (926, 15)

# %%
harris_precincts
# Out:
#      Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0       Harris     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 12           6     Total:      8,814      2,294      6,520      292    2,862
# 13                   VAP:      6,379      1,945      4,434      224    1,916
# 14           7     Total:      1,294         32      1,262        9      754
# 15                   VAP:        987         27        960        9      627
# ...        ...        ...        ...        ...        ...      ...      ...
# 2283                 VAP:      4,987        358      4,629      158    1,774
# 2298      1147     Total:        197         17        180        3       15
# 2299                 VAP:        119         15        104        2        6
# 2300      1148     Total:      2,720        163      2,557      273      578
# 2301                 VAP:      1,970        139      1,831      236      409
#
# ...

# %%
harris_precincts = harris_precincts.reset_index()
harris_precincts
# Out:
#      level_0  index Precincts Population      Total      Anglo  Non-Anglo  \
# 0          0      0    Harris     Total:  4,731,145  1,309,593  3,421,552
# 1          1     12         6     Total:      8,814      2,294      6,520
# 2          2     13                 VAP:      6,379      1,945      4,434
# 3          3     14         7     Total:      1,294         32      1,262
# 4          4     15                 VAP:        987         27        960
# ..       ...    ...       ...        ...        ...        ...        ...
# 921      921   2283                 VAP:      4,987        358      4,629
# 922      922   2298      1147     Total:        197         17        180
# 923      923   2299                 VAP:        119         15        104
# 924      924   2300      1148     Total:      2,720        163      2,557
# 925      925   2301                 VAP:      1,970        139      1,831
#
#        Asian    Black       Hisp        B+H  %Anglo  %Non-Anglo  %Asian  \
# ...

# %%
harris_precincts.drop(['level_0', 'index'], axis=1, inplace=True)

# %%
harris_precincts
# Out:
#     Precincts Population      Total      Anglo  Non-Anglo    Asian    Black  \
# 0      Harris     Total:  4,731,145  1,309,593  3,421,552  392,435  981,484
# 1           6     Total:      8,814      2,294      6,520      292    2,862
# 2                   VAP:      6,379      1,945      4,434      224    1,916
# 3           7     Total:      1,294         32      1,262        9      754
# 4                   VAP:        987         27        960        9      627
# ..        ...        ...        ...        ...        ...      ...      ...
# 921                 VAP:      4,987        358      4,629      158    1,774
# 922      1147     Total:        197         17        180        3       15
# 923                 VAP:        119         15        104        2        6
# 924      1148     Total:      2,720        163      2,557      273      578
# 925                 VAP:      1,970        139      1,831      236      409
#
# ...

# %%
# All remaining precincts are comparable to the target precincts. So, 15 will be selected randomly to compare to the original 15 targeted by BakerRipley.

# %%
target_precincts
# Out:
#      Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 18           9     Total:   4,044    931     3,113    201  1,261   1,640
# 19                   VAP:   3,280    872     2,408    171    890   1,312
# 20          10     Total:   3,587    385     3,202     68    143   2,991
# 21                   VAP:   2,902    332     2,570     55    127   2,379
# 22          11     Total:   3,492    295     3,197     62    194   2,962
# 23                   VAP:   2,784    275     2,509     49    173   2,294
# 88          44     Total:   3,799    564     3,235     70    229   2,924
# 89                   VAP:   2,980    472     2,508     50    187   2,253
# 94          46     Total:   5,033    471     4,562     76    949   3,531
# 95                   VAP:   3,810    425     3,385     62    542   2,767
# 572        285     Total:   5,334    148     5,186     38  1,979   3,188
# 573                  VAP:   3,985    121     3,864     28  1,627   2,215
# ...

# %%
total_pop = target_precincts[target_precincts['Population'] == 'Total:']
va_pop = target_precincts[target_precincts['Population'] == 'VAP:']
total_pop = total_pop.reset_index()
total_pop.drop(['index'], axis=1, inplace=True)
total_pop
# Out:
#    Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 0          9     Total:   4,044    931     3,113    201  1,261   1,640
# 1         10     Total:   3,587    385     3,202     68    143   2,991
# 2         11     Total:   3,492    295     3,197     62    194   2,962
# 3         44     Total:   3,799    564     3,235     70    229   2,924
# 4         46     Total:   5,033    471     4,562     76    949   3,531
# 5        285     Total:   5,334    148     5,186     38  1,979   3,188
# 6        347     Total:   8,019  2,017     6,002    343    260   5,362
# 7        379     Total:   3,190     82     3,108     19  1,395   1,726
# 8        411     Total:   6,917    494     6,423     82    405   5,962
# 9        430     Total:   8,039    724     7,315  1,989  1,403   3,994
# 10       431     Total:  22,307  1,213    21,094  1,930  4,456  14,800
# 11       665     Total:   4,408  2,556     1,852     90    124   1,509
# ...

# %%
#va_pop = va_pop.reset_index()
#va_pop
#va_pop.drop(['index', 'level_0'], axis=1, inplace=True)
#va_pop['Precincts'] = total_pop['Precincts']
va_pop
# Out:
#    Precincts Population   Total  Anglo Non-Anglo  Asian  Black    Hisp  \
# 0          9       VAP:   3,280    872     2,408    171    890   1,312
# 1         10       VAP:   2,902    332     2,570     55    127   2,379
# 2         11       VAP:   2,784    275     2,509     49    173   2,294
# 3         44       VAP:   2,980    472     2,508     50    187   2,253
# 4         46       VAP:   3,810    425     3,385     62    542   2,767
# 5        285       VAP:   3,985    121     3,864     28  1,627   2,215
# 6        347       VAP:   5,783  1,721     4,062    262    183   3,571
# 7        379       VAP:   2,458     78     2,380     16  1,182   1,206
# 8        411       VAP:   4,796    427     4,369     51    320   4,006
# 9        430       VAP:   5,556    560     4,996  1,216    949   2,876
# 10       431       VAP:  15,519    975    14,544  1,309  3,207  10,085
# 11       665       VAP:   3,260  2,015     1,245     57     81     994
# ...

# %%
total_pop.drop(['Population'], axis=1, inplace=True)
va_pop.drop(['Population'], axis=1, inplace=True)
total_pop.rename(columns = {'Total':'Total Population'}, inplace = True)
total_pop['VAP'] = va_pop['Total']
total_pop
# Out:
#    Precincts Total Population  Anglo Non-Anglo  Asian  Black    Hisp     B+H  \
# 0          9            4,044    931     3,113    201  1,261   1,640   2,856
# 1         10            3,587    385     3,202     68    143   2,991   3,115
# 2         11            3,492    295     3,197     62    194   2,962   3,133
# 3         44            3,799    564     3,235     70    229   2,924   3,140
# 4         46            5,033    471     4,562     76    949   3,531   4,453
# 5        285            5,334    148     5,186     38  1,979   3,188   5,126
# 6        347            8,019  2,017     6,002    343    260   5,362   5,565
# 7        379            3,190     82     3,108     19  1,395   1,726   3,081
# 8        411            6,917    494     6,423     82    405   5,962   6,323
# 9        430            8,039    724     7,315  1,989  1,403   3,994   5,281
# 10       431           22,307  1,213    21,094  1,930  4,456  14,800  18,990
# ...

# %%
total_pop = total_pop.apply(pd.to_numeric, errors='ignore')
total_pop.dtypes
# Out:
# Precincts             int64
# Total Population     object
# Anglo                object
# Non-Anglo            object
# Asian                object
# Black                object
# Hisp                 object
# B+H                  object
# %Anglo              float64
# %Non-Anglo          float64
# %Asian              float64
# %Black              float64
# %Hispanic           float64
# %B+H                float64
# VAP                  object
# dtype: object

# %%
total_pop['Total Population']=total_pop['Total Population'].str.replace(',','')
total_pop
total_pop['Total Population'] = pd.to_numeric(total_pop['Total Population'])
total_pop
# Out:
#     Precincts  Total Population  Anglo Non-Anglo  Asian  Black    Hisp  \
# 0           9              4044    931     3,113    201  1,261   1,640
# 1          10              3587    385     3,202     68    143   2,991
# 2          11              3492    295     3,197     62    194   2,962
# 3          44              3799    564     3,235     70    229   2,924
# 4          46              5033    471     4,562     76    949   3,531
# 5         285              5334    148     5,186     38  1,979   3,188
# 6         347              8019  2,017     6,002    343    260   5,362
# 7         379              3190     82     3,108     19  1,395   1,726
# 8         411              6917    494     6,423     82    405   5,962
# 9         430              8039    724     7,315  1,989  1,403   3,994
# 10        431             22307  1,213    21,094  1,930  4,456  14,800
# 11        665              4408  2,556     1,852     90    124   1,509
# ...

# %%
total_pop['VAP']=total_pop['VAP'].str.replace(',','')
total_pop['VAP'] = pd.to_numeric(total_pop['VAP'])
total_pop
# Out:
#     Precincts  Total Population  Anglo Non-Anglo  Asian  Black    Hisp  \
# 0           9              4044    931     3,113    201  1,261   1,640
# 1          10              3587    385     3,202     68    143   2,991
# 2          11              3492    295     3,197     62    194   2,962
# 3          44              3799    564     3,235     70    229   2,924
# 4          46              5033    471     4,562     76    949   3,531
# 5         285              5334    148     5,186     38  1,979   3,188
# 6         347              8019  2,017     6,002    343    260   5,362
# 7         379              3190     82     3,108     19  1,395   1,726
# 8         411              6917    494     6,423     82    405   5,962
# 9         430              8039    724     7,315  1,989  1,403   3,994
# 10        431             22307  1,213    21,094  1,930  4,456  14,800
# 11        665              4408  2,556     1,852     90    124   1,509
# ...

# %%
sns.set_style("darkgrid")
sns.set_context('talk')
plt.figure(figsize=(15,10))
sns.scatterplot(x="Precincts",
               y='VAP',
               size='Total Population',
               data=total_pop,
                hue="%Non-Anglo",
                sizes=(50,2000),
                palette=("GnBu_d"))

plt.xlabel("Precinct Number")
plt.ylabel("Voter Age Population (VAP)")
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=17)
plt.tight_layout()
plt.show()
